# %% [markdown]
# <h1>Excel Analysis Task 10-19 - Emily Smith</h1>

# %%
import numpy as np
import pandas as pd
education_df = pd.read_csv("Excel Analysis Task 10-19.csv")
education_df.head()
# Out:
#    FIPST STABR     LEAID                LEA_NAME               MSTREET_1  \
# 0    1.0    AL  100002.0  Alabama Youth Services              P O Box 66
# 1    1.0    AL  100005.0        Albertville City        107 West Main St
# 2    1.0    AL  100006.0         Marshall County  12380 US Highway 431 S
# 3    1.0    AL  100007.0             Hoover City   2810 Metropolitan Way
# 4    1.0    AL  100008.0            Madison City        211 Celtic Drive
#
#   MSTREET_2 MSTREET_3         MCITY MSTATE     MZIP  ...  \
# 0       NaN       NaN      Mt Meigs     AL  36057.0  ...
# 1       NaN       NaN   Albertville     AL  35950.0  ...
# 2       NaN       NaN  Guntersville     AL  35976.0  ...
# 3       NaN       NaN        Hoover     AL  35243.0  ...
# 4       NaN       NaN       Madison     AL  35758.0  ...
#
#                                        LEA_TYPE_TEXT  \
# 0  Regular public school district that is not a c...
# 1  Regular public school district that is not a c...
# ...

# %% [markdown]
# <h3>Step 1: Calculate the percentage of students in each districts that are Hispanic</h3>

# %%
def percent_hispanic(type_text, his, tot):
    n = len(type_text)
    for i in range(n):
        if type_text[i] == "Regular public school district that is not a component of a supervisory union":
            percent = his/tot
    return(percent)
 
education_df["percent hispanic"] = percent_hispanic(education_df["LEA_TYPE_TEXT"], education_df["All Students - Hispanic"], 
                                         education_df["All Students"])

education_df.head()
#do an "if-than" statement --> if public district print hispanic students/total students (for loop?)
# Out:
#    FIPST STABR     LEAID                LEA_NAME               MSTREET_1  \
# 0    1.0    AL  100002.0  Alabama Youth Services              P O Box 66
# 1    1.0    AL  100005.0        Albertville City        107 West Main St
# 2    1.0    AL  100006.0         Marshall County  12380 US Highway 431 S
# 3    1.0    AL  100007.0             Hoover City   2810 Metropolitan Way
# 4    1.0    AL  100008.0            Madison City        211 Celtic Drive
#
#   MSTREET_2 MSTREET_3         MCITY MSTATE     MZIP  ...  \
# 0       NaN       NaN      Mt Meigs     AL  36057.0  ...
# 1       NaN       NaN   Albertville     AL  35950.0  ...
# 2       NaN       NaN  Guntersville     AL  35976.0  ...
# 3       NaN       NaN        Hoover     AL  35243.0  ...
# 4       NaN       NaN       Madison     AL  35758.0  ...
#
#    All Students - American Indian/Alaska Native All Students - Asian  \
# 0                                           NaN                  NaN
# ...

# %% [markdown]
# <h3>Step 2: Identify the districts where >= 50 percent of the students are Hispanic</h3>

# %%
#do an "if-than" statement --> if >= 50 percent print name of district (for loop?)

# %% [markdown]
# <h3>Step 3: Identify the districts that receive grants of > $100,000</h3>

# %%
#do a for loop --> for all districts with > $100,00, print name of district

# %% [markdown]
# <h3>Step 4: Provide a summary that shows the number of LEAs in each of the blue cells in the excel document.</h3>

# %%
#combine first and third loops ?

# %% [markdown]
# <h3>Step 5: Add 2 or three sentences below the table to describe the findings, focusing on the districts with >= 50% Hispanic students.</h3>
